# %% [markdown]
# # Correlation Analysis

# %% [markdown]
# <a id='top'></a>
#
# <a href=#readdata>Read Data</a>
#
# <a href=#correlation>Correlation</a>
#
# <a href=#remove_columns>Remove Columns</a>
#
# <a href=#conclusions>Conclusions</a>
#
# <a href=#end>End</a>

# %%
# Ignore 'dask' warning

import pandas as pd
import gcsfs
from google.cloud import storage
from pandas import DataFrame
from IPython.display import HTML
from google.cloud.storage import Blob
import datalab.storage as gcs_datalab
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split

from sklearn import preprocessing
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# <a id='readdata'></a>
#
# # Read in data from CSV file
#
# <a href=#top>Top</a>

# %%
data_df = pd.read_csv('../Data_Merging/subset_2018.csv')

# %%
data_df.columns
# Out:
# Index(['Unnamed: 0', 'date_month', 'id_company', 'id_branch',
#        'is_discontinued', 'financial_calamity_outcome', 'qty_employees',
#        'year_qty_employees', 'id_company_creditproxy',
#        'score_payment_assessment', 'amt_revenue', 'year_revenue',
#        'amt_consolidated_revenue', 'year_consolidated_revenue',
#        'amt_consolidated_operating_result',
#        'year_consolidated_operating_result', 'perc_credit_limit_adjustment',
#        'color_credit_status', 'rat_pd', 'score_pd', 'has_increased_risk',
#        'is_sole_proprietor', 'code_sbi_2', 'code_sbi_1',
#        'qty_address_mutations_total', 'qty_address_mutations_month',
#        'has_relocated', 'has_name_change', 'vice_president'],
#       dtype='object')

# %% [markdown]
# <a id='correlation'></a>
# # Correlation Analysis:
#
# <a href=#top>Top</a>

# %%
# Compute the correlation matrix
corr_df = data_df.drop(columns=['Unnamed: 0']).corr()

# %%
corr_df
# Out:
#                                     id_company  id_branch  is_discontinued  \
# id_company                            1.000000   0.622736        -0.036399
# id_branch                             0.622736   1.000000        -0.054239
# is_discontinued                      -0.036399  -0.054239         1.000000
# financial_calamity_outcome           -0.035668  -0.104118        -0.005524
# qty_employees                        -0.017381   0.041575        -0.004520
# year_qty_employees                    0.014728   0.110437        -0.214389
# id_company_creditproxy                0.965202   0.617854        -0.037235
# score_payment_assessment              0.128173   0.122492         0.086719
# amt_revenue                           0.001603   0.003279        -0.000197
# year_revenue                         -0.142331  -0.070974        -0.014104
# amt_consolidated_revenue                   NaN        NaN              NaN
# year_consolidated_revenue            -0.146824  -0.010443        -0.012272
# amt_consolidated_operating_result          NaN        NaN              NaN
# year_consolidated_operating_result   -0.149456   0.007454        -0.015808
# perc_credit_limit_adjustment         -0.036223   0.014451        -0.002402
# score_pd                             -0.012369  -0.034959         0.184646
# has_increased_risk                    0.010296  -0.006184         0.191333
# is_sole_proprietor                         NaN        NaN              NaN
# code_sbi_2                            0.104508   0.104029        -0.037574
# qty_address_mutations_total          -0.002526   0.015961        -0.001087
# qty_address_mutations_month           0.031865   0.072282        -0.006051
# has_relocated                         0.022289   0.024376        -0.004104
# has_name_change                       0.005442   0.011043        -0.002214
# vice_president                       -0.000467  -0.002555        -0.000313
#
#                                     financial_calamity_outcome  qty_employees  \
# id_company                                           -0.035668      -0.017381
# id_branch                                            -0.104118       0.041575
# is_discontinued                                      -0.005524      -0.004520
# financial_calamity_outcome                            1.000000      -0.015888
# qty_employees                                        -0.015888       1.000000
# year_qty_employees                                   -0.472416       0.020709
# id_company_creditproxy                               -0.037494      -0.014565
# score_payment_assessment                              0.020737      -0.033031
# amt_revenue                                          -0.000525      -0.000147
# year_revenue                                          0.029002       0.003302
# amt_consolidated_revenue                                   NaN            NaN
# year_consolidated_revenue                            -0.028124       0.055149
# amt_consolidated_operating_result                          NaN            NaN
# year_consolidated_operating_result                   -0.035621       0.093509
# perc_credit_limit_adjustment                         -0.519241       0.025169
# score_pd                                              0.488182       0.076163
# has_increased_risk                                    0.505554       0.079546
# is_sole_proprietor                                         NaN            NaN
# code_sbi_2                                           -0.046366       0.068542
# qty_address_mutations_total                          -0.003000       0.030091
# qty_address_mutations_month                          -0.017390      -0.003997
# has_relocated                                        -0.012749      -0.005106
# has_name_change                                      -0.007237      -0.001707
# vice_president                                       -0.000837      -0.000290
#
#                                     year_qty_employees  \
# id_company                                    0.014728
# id_branch                                     0.110437
# is_discontinued                              -0.214389
# financial_calamity_outcome                   -0.472416
# qty_employees                                 0.020709
# year_qty_employees                            1.000000
# id_company_creditproxy                        0.018095
# score_payment_assessment                     -0.069547
# amt_revenue                                   0.000968
# year_revenue                                  0.003066
# amt_consolidated_revenue                           NaN
# year_consolidated_revenue                     0.040981
# amt_consolidated_operating_result                  NaN
# year_consolidated_operating_result            0.036682
# perc_credit_limit_adjustment                  0.365798
# score_pd                                     -0.403176
# has_increased_risk                           -0.425067
# is_sole_proprietor                                 NaN
# code_sbi_2                                   -0.006354
# qty_address_mutations_total                   0.003857
# qty_address_mutations_month                   0.018238
# has_relocated                                 0.015410
# has_name_change                               0.008345
# vice_president                               -0.005830
#
#                                     id_company_creditproxy  \
# id_company                                        0.965202
# id_branch                                         0.617854
# is_discontinued                                  -0.037235
# financial_calamity_outcome                       -0.037494
# qty_employees                                    -0.014565
# year_qty_employees                                0.018095
# id_company_creditproxy                            1.000000
# score_payment_assessment                          0.124395
# amt_revenue                                       0.001587
# year_revenue                                     -0.131132
# amt_consolidated_revenue                               NaN
# year_consolidated_revenue                        -0.135670
# amt_consolidated_operating_result                      NaN
# year_consolidated_operating_result               -0.139459
# perc_credit_limit_adjustment                     -0.031958
# score_pd                                         -0.014698
# has_increased_risk                                0.006894
# is_sole_proprietor                                     NaN
# code_sbi_2                                        0.101809
# qty_address_mutations_total                      -0.001126
# qty_address_mutations_month                       0.031593
# has_relocated                                     0.022262
# has_name_change                                   0.005357
# vice_president                                   -0.000507
#
#                                     score_payment_assessment  amt_revenue  \
# id_company                                          0.128173     0.001603
# id_branch                                           0.122492     0.003279
# is_discontinued                                     0.086719    -0.000197
# financial_calamity_outcome                          0.020737    -0.000525
# qty_employees                                      -0.033031    -0.000147
# year_qty_employees                                 -0.069547     0.000968
# id_company_creditproxy                              0.124395     0.001587
# score_payment_assessment                            1.000000    -0.000640
# amt_revenue                                        -0.000640     1.000000
# year_revenue                                       -0.085610     0.008401
# amt_consolidated_revenue                                 NaN          NaN
# year_consolidated_revenue                          -0.063555     0.004459
# amt_consolidated_operating_result                        NaN          NaN
# year_consolidated_operating_result                 -0.081263     0.003472
# perc_credit_limit_adjustment                       -0.138478    -0.000484
# score_pd                                           -0.210475    -0.000571
# has_increased_risk                                 -0.208767    -0.001027
# is_sole_proprietor                                       NaN          NaN
# code_sbi_2                                          0.052684    -0.002723
# qty_address_mutations_total                        -0.004622    -0.000041
# qty_address_mutations_month                         0.032266    -0.000237
# has_relocated                                       0.027541    -0.000175
# has_name_change                                    -0.004756    -0.000099
# vice_president                                     -0.000797    -0.000011
#
#                                     year_revenue       ...        \
# id_company                             -0.142331       ...
# id_branch                              -0.070974       ...
# is_discontinued                        -0.014104       ...
# financial_calamity_outcome              0.029002       ...
# qty_employees                           0.003302       ...
# year_qty_employees                      0.003066       ...
# id_company_creditproxy                 -0.131132       ...
# score_payment_assessment               -0.085610       ...
# amt_revenue                             0.008401       ...
# year_revenue                            1.000000       ...
# amt_consolidated_revenue                     NaN       ...
# year_consolidated_revenue               0.139292       ...
# amt_consolidated_operating_result            NaN       ...
# year_consolidated_operating_result      0.168997       ...
# perc_credit_limit_adjustment           -0.025726       ...
# score_pd                                0.055480       ...
# has_increased_risk                      0.025065       ...
# is_sole_proprietor                           NaN       ...
# code_sbi_2                              0.007371       ...
# qty_address_mutations_total             0.007288       ...
# qty_address_mutations_month            -0.012123       ...
# has_relocated                          -0.010652       ...
# has_name_change                         0.006285       ...
# vice_president                         -0.000777       ...
#
#                                     perc_credit_limit_adjustment  score_pd  \
# id_company                                             -0.036223 -0.012369
# id_branch                                               0.014451 -0.034959
# is_discontinued                                        -0.002402  0.184646
# financial_calamity_outcome                             -0.519241  0.488182
# qty_employees                                           0.025169  0.076163
# year_qty_employees                                      0.365798 -0.403176
# id_company_creditproxy                                 -0.031958 -0.014698
# score_payment_assessment                               -0.138478 -0.210475
# amt_revenue                                            -0.000484 -0.000571
# year_revenue                                           -0.025726  0.055480
# amt_consolidated_revenue                                     NaN       NaN
# year_consolidated_revenue                               0.013394 -0.000580
# amt_consolidated_operating_result                            NaN       NaN
# year_consolidated_operating_result                      0.019449  0.002742
# perc_credit_limit_adjustment                            1.000000 -0.684517
# score_pd                                               -0.684517  1.000000
# has_increased_risk                                     -0.621682  0.964105
# is_sole_proprietor                                           NaN       NaN
# code_sbi_2                                             -0.034726  0.079923
# qty_address_mutations_total                             0.005987  0.001101
# qty_address_mutations_month                             0.006009 -0.017082
# has_relocated                                           0.002561 -0.015730
# has_name_change                                         0.007963 -0.003127
# vice_president                                          0.000303  0.003020
#
#                                     has_increased_risk  is_sole_proprietor  \
# id_company                                    0.010296                 NaN
# id_branch                                    -0.006184                 NaN
# is_discontinued                               0.191333                 NaN
# financial_calamity_outcome                    0.505554                 NaN
# qty_employees                                 0.079546                 NaN
# year_qty_employees                           -0.425067                 NaN
# id_company_creditproxy                        0.006894                 NaN
# score_payment_assessment                     -0.208767                 NaN
# amt_revenue                                  -0.001027                 NaN
# year_revenue                                  0.025065                 NaN
# amt_consolidated_revenue                           NaN                 NaN
# year_consolidated_revenue                    -0.027372                 NaN
# amt_consolidated_operating_result                  NaN                 NaN
# year_consolidated_operating_result           -0.022317                 NaN
# perc_credit_limit_adjustment                 -0.621682                 NaN
# score_pd                                      0.964105                 NaN
# has_increased_risk                            1.000000                 NaN
# is_sole_proprietor                                 NaN                 NaN
# code_sbi_2                                    0.068705                 NaN
# qty_address_mutations_total                   0.000203                 NaN
# qty_address_mutations_month                  -0.014894                 NaN
# has_relocated                                -0.015817                 NaN
# has_name_change                              -0.003738                 NaN
# vice_president                                0.003199                 NaN
#
#                                     code_sbi_2  qty_address_mutations_total  \
# id_company                            0.104508                    -0.002526
# id_branch                             0.104029                     0.015961
# is_discontinued                      -0.037574                    -0.001087
# financial_calamity_outcome           -0.046366                    -0.003000
# qty_employees                         0.068542                     0.030091
# year_qty_employees                   -0.006354                     0.003857
# id_company_creditproxy                0.101809                    -0.001126
# score_payment_assessment              0.052684                    -0.004622
# amt_revenue                          -0.002723                    -0.000041
# year_revenue                          0.007371                     0.007288
# amt_consolidated_revenue                   NaN                          NaN
# year_consolidated_revenue            -0.002493                     0.023633
# amt_consolidated_operating_result          NaN                          NaN
# year_consolidated_operating_result    0.053321                     0.022711
# perc_credit_limit_adjustment         -0.034726                     0.005987
# score_pd                              0.079923                     0.001101
# has_increased_risk                    0.068705                     0.000203
# is_sole_proprietor                         NaN                          NaN
# code_sbi_2                            1.000000                     0.007835
# qty_address_mutations_total           0.007835                     1.000000
# qty_address_mutations_month           0.017455                     0.171758
# has_relocated                         0.015161                     0.064891
# has_name_change                       0.005757                     0.014836
# vice_president                        0.005390                    -0.000065
#
#                                     qty_address_mutations_month  \
# id_company                                             0.031865
# id_branch                                              0.072282
# is_discontinued                                       -0.006051
# financial_calamity_outcome                            -0.017390
# qty_employees                                         -0.003997
# year_qty_employees                                     0.018238
# id_company_creditproxy                                 0.031593
# score_payment_assessment                               0.032266
# amt_revenue                                           -0.000237
# year_revenue                                          -0.012123
# amt_consolidated_revenue                                    NaN
# year_consolidated_revenue                             -0.006963
# amt_consolidated_operating_result                           NaN
# year_consolidated_operating_result                    -0.009376
# perc_credit_limit_adjustment                           0.006009
# score_pd                                              -0.017082
# has_increased_risk                                    -0.014894
# is_sole_proprietor                                          NaN
# code_sbi_2                                             0.017455
# qty_address_mutations_total                            0.171758
# qty_address_mutations_month                            1.000000
# has_relocated                                          0.732214
# has_name_change                                        0.048148
# vice_president                                        -0.000378
#
#                                     has_relocated  has_name_change  \
# id_company                               0.022289         0.005442
# id_branch                                0.024376         0.011043
# is_discontinued                         -0.004104        -0.002214
# financial_calamity_outcome              -0.012749        -0.007237
# qty_employees                           -0.005106        -0.001707
# year_qty_employees                       0.015410         0.008345
# id_company_creditproxy                   0.022262         0.005357
# score_payment_assessment                 0.027541        -0.004756
# amt_revenue                             -0.000175        -0.000099
# year_revenue                            -0.010652         0.006285
# amt_consolidated_revenue                      NaN              NaN
# year_consolidated_revenue               -0.007819         0.000967
# amt_consolidated_operating_result             NaN              NaN
# year_consolidated_operating_result      -0.010522         0.001603
# perc_credit_limit_adjustment             0.002561         0.007963
# score_pd                                -0.015730        -0.003127
# has_increased_risk                      -0.015817        -0.003738
# is_sole_proprietor                            NaN              NaN
# code_sbi_2                               0.015161         0.005757
# qty_address_mutations_total              0.064891         0.014836
# qty_address_mutations_month              0.732214         0.048148
# has_relocated                            1.000000         0.037106
# has_name_change                          0.037106         1.000000
# vice_president                          -0.000278         0.030480
#
#                                     vice_president
# id_company                               -0.000467
# id_branch                                -0.002555
# is_discontinued                          -0.000313
# financial_calamity_outcome               -0.000837
# qty_employees                            -0.000290
# year_qty_employees                       -0.005830
# id_company_creditproxy                   -0.000507
# score_payment_assessment                 -0.000797
# amt_revenue                              -0.000011
# year_revenue                             -0.000777
# amt_consolidated_revenue                       NaN
# year_consolidated_revenue                -0.000863
# amt_consolidated_operating_result              NaN
# year_consolidated_operating_result       -0.000375
# perc_credit_limit_adjustment              0.000303
# score_pd                                  0.003020
# has_increased_risk                        0.003199
# is_sole_proprietor                             NaN
# code_sbi_2                                0.005390
# qty_address_mutations_total              -0.000065
# qty_address_mutations_month              -0.000378
# has_relocated                            -0.000278
# has_name_change                           0.030480
# vice_president                            1.000000
#
# [24 rows x 24 columns]

# %%
# Generate a mask for the upper triangle
mask = np.zeros_like(corr_df, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True


# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_df, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# <a id='remove_columns'</a>
# # Limit Number of Features
#
# <a href=#top>Top</a>

# %% [markdown]
# Remove some columns with no correlation (b/c it is constant, or categorical...)

# %%
# Compute the correlation matrix
corrII_df = data_df.drop(columns=['Unnamed: 0',
                                      'id_company',
                                      'id_branch',
                                      'year_qty_employees',
                                      'id_company_creditproxy',
                                      'year_revenue',
                                      'amt_consolidated_revenue',
                                      'year_consolidated_revenue',
                                      'amt_consolidated_operating_result',
                                      'year_consolidated_operating_result',
                                      'is_sole_proprietor',
                                      'qty_address_mutations_total',
                                      'qty_address_mutations_month',
                                      'has_name_change',
                                      'vice_president']).corr()

# %%
# Generate a mask for the upper triangle
mask = np.zeros_like(corrII_df, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True


# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corrII_df, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# <a id='conclusions'></a>
# # Conclusions:
#
# - The 'has_relocated' column has some correlation with 'score_payment_assessment' column, and very little correlation with any other column.
# - 'The 'score_pd' and 'has_increased_risk' are highly correlated - perhaps only use one or the other during modelling.
# -  There is a strong (negative) correlation between 'perc_credit_limit_adjustment' and 'financial_calamity_outcome'.

# %% [markdown]
# <a id='end'></a>
#
# <a href=#top>Top</a>
#
# # End
